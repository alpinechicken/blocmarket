# %%
# My little btc quote bot

# %%
import requests
import json
import numpy as np
import pandas as pd
import time

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#baseurl = 'https://blocmarket.herokuapp.com/'
# baseurl = 'http://127.0.0.1:5000/'
baseurl = 'http://127.0.0.1:7000/'

# %%
# set up quote api
apikey = 'VVOJSV9CUU9JRCSE'
quoteurl = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE&from_currency=BTC&to_currency=USD&apikey=' + apikey
# Test realtime quote 
response = requests.get(quoteurl, headers=headers)
# Look at the quote
response.json()
# Out:
# {'Realtime Currency Exchange Rate': {'1. From_Currency Code': 'BTC',
#   '2. From_Currency Name': 'Bitcoin',
#   '3. To_Currency Code': 'USD',
#   '4. To_Currency Name': 'United States Dollar',
#   '5. Exchange Rate': '3647.09000000',
#   '6. Last Refreshed': '2019-02-09 23:00:21',
#   '7. Time Zone': 'UTC'}}

# %%
quote = float(response.json()['Realtime Currency Exchange Rate']['5. Exchange Rate'])
quote
# Out:
# 3647.09

# %%
# Create a new user
url = baseurl +'createUser'
headers = {'content-type': 'application/json'}
content = {}
response = requests.post(url, data=json.dumps(content), headers=headers)

# %%
# View response as json
response.json()
# Out:
# {'signingKey': '8d457749b3d3028a4375c9812b6b2051c545f0c3f2747069b90873b64b8f176a',
#  'traderId': '1',
#  'verifyKey': '527d39cf001e85321ba9519e57c2e617c122a96182cbbac442c1516b0dae1596'}

# %%
# Copy keys and traderid from response
sk = response.json()['signingKey']
vk = response.json()['verifyKey']
tId = int(response.json()['traderId'])

# %%
# Create a new market
mkRtId = 1
mkBrId = 1


url = baseurl + 'createMarket'
content_makemarket = {"signingKey": sk,
                        "traderId": tId, 
                        "verifyKey": vk,
                        "marketRootId": mkRtId, 
                        "marketBranchId": mkBrId, 
                        "marketMin": 2500,
                        "marketMax":4500}
# Post market
response = requests.post(url, data=json.dumps(content_makemarket), headers=headers)

# %%
# response = requests.post(url, data=json.dumps(content_makemarket), headers=headers)
# View response as json
response.json()
# Out:
# {'allChecks': "{'inputChk': True, 'marketLimitChk': True, 'traderIdChk': True, 'marketId': '1', 'marketRangeChk': True, 'marketIndChk': True, 'sigChk': True, 'chainChk': True, 'ownerChk': True, 'timeChk': True}",
#  'checks': 'True',
#  'marketBranchId': 1,
#  'marketId': 1,
#  'marketMax': 4500,
#  'marketMin': 2500,
#  'marketRootId': 1,
#  'traderId': 1}

# %%
# Save market id from response
mkId = response.json()['marketId']
quote
# Out:
# 3647.09

# %%
# Create a trade
tradeurl = baseurl+'createTrade'

content_maketrade = {"signingKey": sk,
                     "traderId": tId,
                     "verifyKey": vk,
                     "marketId": int(mkId),
                     "price":quote,
                     "quantity": 1}
response = requests.post(tradeurl, data=json.dumps(content_maketrade), headers=headers)

# %%
# View response as json
response.json()
# Out:
# {'allChecks': "{'inputChk': True, 'traderIdChk': True, 'marketChk': True, 'sigChk': True, 'chainChk': True, 'timeChk': True, 'colChk': True}",
#  'checks': 'True',
#  'marketId': 1,
#  'price': 3647.09,
#  'quantity': 1,
#  'traderId': 1}

# %%
content_makemarket
# Out:
# {'signingKey': 'b95de2fdcc31bb6bb83f7883f634911efa20a8e9be32595b5c60666fcf08fac2',
#  'traderId': 2,
#  'verifyKey': 'c888bdd3d2abdf74fd5f22dd6463b916d3ea03b1c3996b897f35312a6ddca562',
#  'marketRootId': 2,
#  'marketBranchId': 10,
#  'marketMin': 0,
#  'marketMax': 0.7}

# %%
stillQuoting = True
i=0
while stillQuoting==True:
    # Quote from source
    i+=1
    response = requests.get(quoteurl, headers=headers)
    quote = float(response.json()['Realtime Currency Exchange Rate']['5. Exchange Rate'])
    # Make a bid
    content_maketrade['price'] = quote-1
    content_maketrade['quantity'] =1
    response = requests.post(tradeurl, data=json.dumps(content_maketrade), headers=headers)
    # Make an offer
    content_maketrade['price'] = quote+1
    content_maketrade['quantity'] = -1
    response = requests.post(tradeurl, data=json.dumps(content_maketrade), headers=headers)
    time.sleep(3*60)
    
    # Remove bid 
    content_maketrade['price'] = quote-1
    content_maketrade['quantity'] =-1
    response = requests.post(tradeurl, data=json.dumps(content_maketrade), headers=headers)
    # Remove offer
    content_maketrade['price'] = quote+1
    content_maketrade['quantity'] = 1
    response = requests.post(tradeurl, data=json.dumps(content_maketrade), headers=headers)
    print('Price for iteration ' + str(i) + ' : ' + str(content_maketrade['price']))
# Out:
# Price for iteration 1 : 3648.31
# Price for iteration 2 : 3647.45
# Price for iteration 3 : 3648.88
# Price for iteration 4 : 3649.23
# Price for iteration 5 : 3645.42
# Price for iteration 6 : 3645.45
# Price for iteration 7 : 3645.96
# Price for iteration 8 : 3646.43
# Price for iteration 9 : 3646.43
# Price for iteration 10 : 3646.71
# Price for iteration 11 : 3645.72
# Price for iteration 12 : 3647.95
# Price for iteration 13 : 3648.16
# Price for iteration 14 : 3649.11
# Price for iteration 15 : 3650.56
# Price for iteration 16 : 3652.77
# Price for iteration 17 : 3651.49
# Price for iteration 18 : 3650.15
# Price for iteration 19 : 3651.87
# Price for iteration 20 : 3653.09
# Price for iteration 21 : 3654.16
# Price for iteration 22 : 3653.27
# Price for iteration 23 : 3655.63
# Price for iteration 24 : 3655.86
# Price for iteration 25 : 3657.99
# Price for iteration 26 : 3657.54
# Price for iteration 27 : 3658.77
# Price for iteration 28 : 3656.92
# Price for iteration 29 : 3658.78
# Price for iteration 30 : 3658.93
# Price for iteration 31 : 3658.94
# Price for iteration 32 : 3657.91
# Price for iteration 33 : 3657.26
# Price for iteration 34 : 3653.02
# Price for iteration 35 : 3653.9
# Price for iteration 36 : 3654.97
# Price for iteration 37 : 3653.79
# Price for iteration 38 : 3653.18
# Price for iteration 39 : 3645.67
# Price for iteration 40 : 3646.13
# Price for iteration 41 : 3646.47
# Price for iteration 42 : 3645.84
# Price for iteration 43 : 3645.98
# Price for iteration 44 : 3646.13
# Price for iteration 131 : 3646.73
# Price for iteration 132 : 3646.41
# Price for iteration 133 : 3647.44
# Price for iteration 134 : 3647.99
# Price for iteration 135 : 3645.49
# Price for iteration 136 : 3646.4

# %%
content_maketrade
# Out:
# {'signingKey': '7f483db2a4d837caf55d7b5b5d5b8923faa1a21802f817bfe00b07aa13187bef',
#  'traderId': 1,
#  'verifyKey': '2985c55dde343a6f024867acca6b64263f171aa5e5b1ee65620b1763b86fd37e',
#  'marketId': 1,
#  'price': 3625.7,
#  'quantity': -1}

# %%
content_maketrade['quantity'] = quote

# %%
response = requests.post(tradeurl, data=json.dumps(content_maketrade), headers=headers)

# %%
response.json()
# Out:
# {'allChecks': "{'inputChk': True, 'traderIdChk': True, 'marketChk': True, 'sigChk': True, 'chainChk': True, 'timeChk': True, 'colChk': True}",
#  'checks': 'True',
#  'marketId': 1,
#  'price': 3625.7,
#  'quantity': 2.0,
#  'traderId': 1}

# %%
# Out:
# 'http://127.0.0.1:7000/createTrade'

# %%
# View summary of trader for a particular trader
url = baseurl+'viewTradeSummary'
content = {'traderId': int(tId)}
response = requests.post(url, data=json.dumps(content), headers=headers, stream=True)

# %%
pd.read_json(response.json())
# Out:
#     marketId    price  quantity  traderId  iMatched            timeStampUTC  \
# 0          1     0.50         1         1     False 2019-02-09 07:42:46.453
# 1          1  3654.85        -1         1     False 2019-02-09 07:45:23.233
# 10         1  3654.42        -1         1     False 2019-02-09 07:46:27.127
# 11         1  3652.42        -1         1     False 2019-02-09 07:49:27.231
# 12         1  3649.60        -1         1     False 2019-02-09 07:49:29.240
# 13         1  3647.60        -1         1     False 2019-02-09 07:52:29.344
# 14         1  3652.97        -1         1     False 2019-02-09 07:52:31.267
# 15         1  3650.97        -1         1     False 2019-02-09 07:55:31.372
# 16         1  3648.03        -1         1     False 2019-02-09 07:55:33.366
# 17         1  3646.03        -1         1     False 2019-02-09 07:58:33.471
# 18         1  3648.76        -1         1     False 2019-02-09 07:58:35.702
# 19         1  3646.76        -1         1     False 2019-02-09 08:01:35.799
# 2          1  3652.85        -1         1     False 2019-02-09 07:45:26.333
# 20         1  3641.76        -1         1     False 2019-02-09 08:01:38.472
# 21         1  3639.76        -1         1     False 2019-02-09 08:04:38.580
# 22         1  3635.70        -1         1     False 2019-02-09 08:04:40.340
# 23         1  3633.70        -1         1     False 2019-02-09 08:07:40.445
# 24         1  3634.78        -1         1     False 2019-02-09 08:07:42.309
# 25         1  3632.78        -1         1     False 2019-02-09 08:10:42.425
# 26         1  3633.01        -1         1     False 2019-02-09 08:10:44.444
# 27         1  3631.01        -1         1     False 2019-02-09 08:13:44.549
# 28         1  3636.28        -1         1     False 2019-02-09 08:13:46.388
# 29         1  3634.28        -1         1     False 2019-02-09 08:16:46.482
# 3          1  3654.24        -1         1     False 2019-02-09 07:45:53.582
# 30         1  3636.88        -1         1     False 2019-02-09 08:16:51.892
# 21             1               1       2500       4500           1139.76
# 22             1               1       2500       4500           1135.70
# 23             1               1       2500       4500           1133.70
# 24             1               1       2500       4500           1134.78
# 25             1               1       2500       4500           1132.78
# 26             1               1       2500       4500           1133.01
# 27             1               1       2500       4500           1131.01
# 28             1               1       2500       4500           1136.28
# 29             1               1       2500       4500           1134.28
# 3              1               1       2500       4500           1154.24
# 30             1               1       2500       4500           1136.88
# 31             1               1       2500       4500           1134.88
# 32             1               1       2500       4500           1131.86
# 33             1               1       2500       4500           1129.86
# 34             1               1       2500       4500           1131.04
# 35             1               1       2500       4500           1129.04
# ..           ...             ...        ...        ...               ...
# 71             1               1       2500       4500           1120.37
# 72             1               1       2500       4500           1127.42
# 73             1               1       2500       4500           1125.42
# 74             1               1       2500       4500           1126.39
# 75             1               1       2500       4500           1124.39
# 76             1               1       2500       4500           1126.30
# 77             1               1       2500       4500           1124.30
# 78             1               1       2500       4500           1126.25
# 79             1               1       2500       4500           1124.25
# 8              1               1       2500       4500           1152.24
# 80             1               1       2500       4500           1128.09
# 81             1               1       2500       4500           1126.09
# 82             1               1       2500       4500           1126.94
# 83             1               1       2500       4500           1124.94
# 84             1               1       2500       4500           1128.62
# 85             1               1       2500       4500           1126.62
# 86             1               1       2500       4500           1128.98
# 87             1               1       2500       4500           1126.98
# 88             1               1       2500       4500           1128.58
# 89             1               1       2500       4500           1126.58
# 9              1               1       2500       4500           1154.25
# 90             1               1       2500       4500           1127.24
# 91             1               1       2500       4500           1125.24
# 92             1               1       2500       4500           1125.70
# 93             1               1       2500       4500           1125.70
# 94             1               1       2500       4500           2251.40
# 95             1               1       2500       4500           1125.70
# 96             1               1       2500       4500          -1125.70
# 97             1               1       2500       4500           1125.70
# 98             1               1       2500       4500          -1125.70
#
#     marketMaxOutcome
# 0            4499.50
# 1            -845.15
# 10           -845.58
# 11           -847.58
# 12           -850.40
# 13           -852.40
# 14           -847.03
# 15           -849.03
# 16           -851.97
# 17           -853.97
# 18           -851.24
# 19           -853.24
# 2            -847.15
# 20           -858.24
# 21           -860.24
# 22           -864.30
# 23           -866.30
# 24           -865.22
# 25           -867.22
# 26           -866.99
# 27           -868.99
# 28           -863.72
# 29           -865.72
# 3            -845.76
# 30           -863.12
# 31           -865.12
# 32           -868.14
# 33           -870.14
# 34           -868.96
# 35           -870.96
# ..               ...
# 71           -879.63
# 72           -872.58
# 73           -874.58
# 74           -873.61
# 75           -875.61
# 76           -873.70
# 77           -875.70
# 78           -873.75
# 79           -875.75
# 8            -847.76
# 80           -871.91
# 81           -873.91
# 82           -873.06
# 83           -875.06
# 84           -871.38
# 85           -873.38
# 86           -871.02
# 87           -873.02
# 88           -871.42
# 89           -873.42
# 9            -845.75
# 90           -872.76
# 91           -874.76
# 92           -874.30
# 93           -874.30
# 94          -1748.60
# 95           -874.30
# 96            874.30
# 97           -874.30
# 98            874.30
#
# [99 rows x 12 columns]
