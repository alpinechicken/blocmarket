# %%
from BetfairBot import BetfairBot
appKey = 'iw8UsiHCP1GSs213'
marketId = '1.165721356'
bot = BetfairBot(betfairMarketId=marketId)
# Get SOID token
bot.getBetfairSessionToken(betfairPassword='ee', betfairAppKey = appKey)



#from BetfairBot import BetfairBot
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
vars(bot)
# Out:
# {'TEST_MODE': True,
#  'botName': 'marketmaker',
#  'blocurl': 'http://127.0.0.1:5000/',
#  'blocheaders': {'content-type': 'application/json'},
#  'updateFrequency': 10,
#  'betfairMarketId': '1.165721356',
#  'betfairAppKey': 'iw8UsiHCP1GSs213',
#  'betfairSessionKey': 'FRkq28qFs2pcIk0IMxEi0/NTWF6oKaubgK/OAkAsj94=',
#  'quoteSource': 'betfair',
#  'localEventId': '',
#  'localMarketId': '',
#  'orderBook': [],
#  'marketDetails': [],
#  'currentOrders': []}

# %%
bot.getMarketDetails()
# Out:
# {'marketId': '1.165721356',
#  'marketName': 'Match Odds',
#  'marketStartTime': '2019-12-11T05:00:00.000Z',
#  'description': {'persistenceEnabled': True,
#   'bspMarket': False,
#   'marketTime': '2019-12-11T05:00:00.000Z',
#   'suspendTime': '2019-12-11T05:00:00.000Z',
#   'bettingType': 'ODDS',
#   'turnInPlayEnabled': True,
#   'marketType': 'MATCH_ODDS',
#   'regulator': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'marketBaseRate': 5.0,
#   'discountAllowed': True,
#   'wallet': 'UK wallet',
#   'rules': '<b>Market Information</b><br>For further information please see <a href=http://content.betfair.com/aboutus/content.asp?sWhichKey=Rules%20and%20Regulations#undefined.do style=color:0163ad; text-decoration: underline; target=_blank>Rules & Regs</a>.<br><br> Who will win this Test match? At the start of scheduled play all unmatched bets will be cancelled and this market will be turned in-play. This market will not be actively managed therefore it is the responsibility of all users to manage their own positions. Competition Rules apply. <br><br>Customers should be aware that:<br><br><li><b/>Transmissions described as “live” by some broadcasters may actually be delayed</li><br><li>The extent of any such delay may vary, depending on the set-up through which they are receiving pictures or data.</b></li><br>\n<ul><li><b>If the official result is a Tied Match in any Test, County or Limited Overs Match then all bets on Match Odds markets will be void</b></li><br><li>At the conclusion of each days play this market will revert to a non in-play status with no time delay in effect then at the start of the following days play this market will be turned in-play again with unmatched bets <b><FONT COLOR="red">not</FONT></b> cancelled.</li>',
#   'rulesHasDate': True,
#   'priceLadderDescription': {'type': 'CLASSIC'}},
#  'totalMatched': 189941.41351500002,
#  'runners': [{'selectionId': 7461,
#    'runnerName': 'Pakistan',
#    'handicap': 0.0,
#    'sortPriority': 1,
#    'metadata': {'runnerId': '7461'}},
#   {'selectionId': 7337,
#    'runnerName': 'Sri Lanka',
#    'handicap': 0.0,
#    'sortPriority': 2,
#    'metadata': {'runnerId': '7337'}},
#   {'selectionId': 60443,
#    'runnerName': 'The Draw',
#    'handicap': 0.0,
#    'sortPriority': 3,
#    'metadata': {'runnerId': '60443'}}],
#  'eventType': {'id': '4', 'name': 'Cricket'},
#  'competition': {'id': '11365612', 'name': 'Test Matches'},
#  'event': {'id': '29603083',
#   'name': 'Pakistan v Sri Lanka (1st Match)',
#   'countryCode': 'GB',
#   'timezone': 'GMT',
#   'openDate': '2019-12-11T05:00:00.000Z'}}

# %%
bot.getCurrentOrders()
# Out:
# [{'betId': '188069858840',
#   'marketId': '1.165721356',
#   'selectionId': 7461,
#   'handicap': 0.0,
#   'priceSize': {'price': 1.9, 'size': 5.28},
#   'bspLiability': 0.0,
#   'side': 'BACK',
#   'status': 'EXECUTION_COMPLETE',
#   'persistenceType': 'LAPSE',
#   'orderType': 'LIMIT',
#   'placedDate': '2019-12-08T03:18:44.000Z',
#   'matchedDate': '2019-12-08T08:31:17.000Z',
#   'averagePriceMatched': 1.9,
#   'sizeMatched': 5.28,
#   'sizeRemaining': 0.0,
#   'sizeLapsed': 0.0,
#   'sizeCancelled': 0.0,
#   'sizeVoided': 0.0,
#   'regulatorCode': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'customerStrategyRef': 'marketmaker'},
#  {'betId': '188069859734',
#   'marketId': '1.165721356',
#   'selectionId': 7461,
#   'handicap': 0.0,
#   'priceSize': {'price': 1.89, 'size': 5.28},
#   'bspLiability': 0.0,
#   'side': 'LAY',
#   'status': 'EXECUTION_COMPLETE',
#   'persistenceType': 'LAPSE',
#   'orderType': 'LIMIT',
#   'placedDate': '2019-12-08T03:18:46.000Z',
#   'matchedDate': '2019-12-08T04:57:16.000Z',
#   'averagePriceMatched': 1.89,
#   'sizeMatched': 5.28,
#   'sizeRemaining': 0.0,
#   'sizeLapsed': 0.0,
#   'sizeCancelled': 0.0,
#   'sizeVoided': 0.0,
#   'regulatorCode': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'customerStrategyRef': 'marketmaker'},
#  {'betId': '188074478548',
#   'marketId': '1.165721356',
#   'selectionId': 7337,
#   'handicap': 0.0,
#   'priceSize': {'price': 4.2, 'size': 5.000000000000001},
#   'bspLiability': 0.0,
#   'side': 'LAY',
#   'status': 'EXECUTION_COMPLETE',
#   'persistenceType': 'LAPSE',
#   'orderType': 'LIMIT',
#   'placedDate': '2019-12-08T04:43:31.000Z',
#   'matchedDate': '2019-12-08T08:25:06.000Z',
#   'averagePriceMatched': 4.2,
#   'sizeMatched': 5.000000000000001,
#   'sizeRemaining': 0.0,
#   'sizeLapsed': 0.0,
#   'sizeCancelled': 0.0,
#   'sizeVoided': 0.0,
#   'regulatorCode': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'customerStrategyRef': 'marketmaker'},
#  {'betId': '188074483399',
#   'marketId': '1.165721356',
#   'selectionId': 60443,
#   'handicap': 0.0,
#   'priceSize': {'price': 4.3, 'size': 5.0},
#   'bspLiability': 0.0,
#   'side': 'BACK',
#   'status': 'EXECUTION_COMPLETE',
#   'persistenceType': 'LAPSE',
#   'orderType': 'LIMIT',
#   'placedDate': '2019-12-08T04:43:35.000Z',
#   'matchedDate': '2019-12-08T08:25:06.000Z',
#   'averagePriceMatched': 4.3,
#   'sizeMatched': 5.0,
#   'sizeRemaining': 0.0,
#   'sizeLapsed': 0.0,
#   'sizeCancelled': 0.0,
#   'sizeVoided': 0.0,
#   'regulatorCode': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'customerStrategyRef': 'marketmaker'},
#  {'betId': '188074487914',
#   'marketId': '1.165721356',
#   'selectionId': 60443,
#   'handicap': 0.0,
#   'priceSize': {'price': 4.1, 'size': 5.0},
#   'bspLiability': 0.0,
#   'side': 'LAY',
#   'status': 'EXECUTION_COMPLETE',
#   'persistenceType': 'LAPSE',
#   'orderType': 'LIMIT',
#   'placedDate': '2019-12-08T04:43:40.000Z',
#   'matchedDate': '2019-12-08T08:42:15.000Z',
#   'averagePriceMatched': 4.099999999999999,
#   'sizeMatched': 5.0,
#   'sizeRemaining': 0.0,
#   'sizeLapsed': 0.0,
#   'sizeCancelled': 0.0,
#   'sizeVoided': 0.0,
#   'regulatorCode': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'customerStrategyRef': 'marketmaker'},
#  {'betId': '188074509671',
#   'marketId': '1.165721356',
#   'selectionId': 7337,
#   'handicap': 0.0,
#   'priceSize': {'price': 4.3, 'size': 5.0},
#   'bspLiability': 0.0,
#   'side': 'BACK',
#   'status': 'EXECUTION_COMPLETE',
#   'persistenceType': 'LAPSE',
#   'orderType': 'LIMIT',
#   'placedDate': '2019-12-08T04:44:02.000Z',
#   'matchedDate': '2019-12-09T00:57:54.000Z',
#   'averagePriceMatched': 4.3,
#   'sizeMatched': 5.0,
#   'sizeRemaining': 0.0,
#   'sizeLapsed': 0.0,
#   'sizeCancelled': 0.0,
#   'sizeVoided': 0.0,
#   'regulatorCode': 'MALTA LOTTERIES AND GAMBLING AUTHORITY',
#   'customerStrategyRef': 'marketmaker'}]

# %%
bot.getOrderBook()
# Out:
# {'marketId': '1.165721356',
#  'isMarketDataDelayed': True,
#  'status': 'OPEN',
#  'betDelay': 0,
#  'bspReconciled': False,
#  'complete': True,
#  'inplay': False,
#  'numberOfWinners': 1,
#  'numberOfRunners': 3,
#  'numberOfActiveRunners': 3,
#  'lastMatchTime': '2019-12-10T11:27:05.622Z',
#  'totalMatched': 189760.46,
#  'totalAvailable': 2734029.44,
#  'crossMatching': True,
#  'runnersVoidable': False,
#  'version': 3076543204,
#  'runners': [{'selectionId': 7461,
#    'handicap': 0.0,
#    'status': 'ACTIVE',
#    'lastPriceTraded': 2.12,
#    'totalMatched': 0.0,
#    'ex': {'availableToBack': [{'price': 2.08, 'size': 138.13},
#      {'price': 2.06, 'size': 359.95},
#      {'price': 2.04, 'size': 218.76}],
#     'availableToLay': [{'price': 2.12, 'size': 48.02},
#      {'price': 2.14, 'size': 1592.82},
#      {'price': 2.2, 'size': 890.33}],
#     'tradedVolume': []}},
#   {'selectionId': 7337,
#    'handicap': 0.0,
#    'status': 'ACTIVE',
#    'lastPriceTraded': 6.2,
#    'totalMatched': 0.0,
#    'ex': {'availableToBack': [{'price': 6.2, 'size': 1635.18},
#      {'price': 6.0, 'size': 533.63},
#      {'price': 5.8, 'size': 498.75}],
#     'availableToLay': [{'price': 6.4, 'size': 110.96},
#      {'price': 6.6, 'size': 324.53},
#      {'price': 6.8, 'size': 21.68}],
#     'tradedVolume': []}},
#   {'selectionId': 60443,
#    'handicap': 0.0,
#    'status': 'ACTIVE',
#    'lastPriceTraded': 2.72,
#    'totalMatched': 0.0,
#    'ex': {'availableToBack': [{'price': 2.72, 'size': 60.02},
#      {'price': 2.7, 'size': 1134.44},
#      {'price': 2.64, 'size': 81.33}],
#     'availableToLay': [{'price': 2.76, 'size': 38.11},
#      {'price': 2.78, 'size': 113.05},
#      {'price': 2.8, 'size': 139.52}],
#     'tradedVolume': []}}]}

# %%
bot.setupLocalData()
# Out:
# Event already exists.
# Market already exists

# %%
bot.scrapeCurrentQuote()

# %%
bot.TEST_MODE = False
bot.run()
# Out:
# 21:33:13.102320
# betId           NaN
# handicap          0
# price          2.12
# selectionId    7461
# side           BACK
# size              5
# 21:33:15.200014
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side            LAY
# size              5
# 21:33:17.295665
# betId           NaN
# handicap          0
# price          6.58
# selectionId    7337
# side           BACK
# size              5
# 21:33:19.398666
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 21:33:21.625152
# betId            NaN
# handicap           0
# price           2.72
# selectionId    60443
# side            BACK
# size               5
# 21:33:23.752309
# betId            NaN
# handicap           0
# price            2.7
# selectionId    60443
# side             LAY
# size               5
# 21:33:41.535818
# betId           NaN
# handicap          0
# price          2.08
# selectionId    7461
# side            LAY
# size              5
# 21:33:43.650938
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:33:47.952463
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:33:52.338675
# betId            NaN
# handicap           0
# price           2.76
# selectionId    60443
# side            BACK
# size               5
# 21:34:11.756922
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side            LAY
# size              5
# 21:34:16.264095
# betId           NaN
# handicap          0
# price          6.58
# selectionId    7337
# side           BACK
# size              5
# 21:34:20.689297
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 21:34:24.987506
# betId            NaN
# handicap           0
# price           2.72
# selectionId    60443
# side            BACK
# size               5
# 21:34:42.238305
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side            LAY
# size              5
# 21:34:44.298268
# betId           NaN
# handicap          0
# price          6.58
# selectionId    7337
# side           BACK
# size              5
# 21:34:48.637186
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 21:35:07.762687
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side           BACK
# size              5
# 21:35:12.151058
# betId           NaN
# handicap          0
# price          6.61
# selectionId    7337
# side            LAY
# size              5
# 21:35:31.710783
# betId           NaN
# handicap          0
# price          6.61
# selectionId    7337
# side            LAY
# size              5
# 21:35:48.735464
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side           BACK
# size              5
# 21:35:50.899244
# betId           NaN
# handicap          0
# price          2.08
# selectionId    7461
# side            LAY
# size              5
# 21:35:53.155357
# betId           NaN
# handicap          0
# price          6.78
# selectionId    7337
# side           BACK
# size              5
# 21:35:57.842401
# betId           NaN
# handicap          0
# price          6.61
# selectionId    7337
# side            LAY
# size              5
# 21:36:17.118398
# betId           NaN
# handicap          0
# price          2.12
# selectionId    7461
# side           BACK
# size              5
# 21:36:21.331572
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:36:23.448063
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:36:42.421785
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:36:46.987519
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:37:05.923672
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side           BACK
# size              5
# 21:37:10.212652
# betId           NaN
# handicap          0
# price          6.78
# selectionId    7337
# side           BACK
# size              5
# 21:37:14.396525
# betId           NaN
# handicap          0
# price          6.61
# selectionId    7337
# side            LAY
# size              5
# 21:37:31.028806
# betId           NaN
# handicap          0
# price          2.12
# selectionId    7461
# side           BACK
# size              5
# 21:37:35.251097
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:37:39.561040
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:37:58.356309
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:38:02.700431
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:38:21.402327
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:38:25.566602
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:38:44.110436
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:38:48.305176
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:39:08.142922
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:39:12.180520
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:39:30.567794
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:39:34.707283
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:39:53.205057
# betId           NaN
# handicap          0
# price          6.58
# selectionId    7337
# side           BACK
# size              5
# 21:39:57.337028
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 21:40:16.104238
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:40:20.141053
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:40:22.162913
# betId            NaN
# handicap           0
# price            2.7
# selectionId    60443
# side             LAY
# size               5
# 21:40:40.756765
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:40:44.908815
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:40:47.011001
# betId            NaN
# handicap           0
# price            2.7
# selectionId    60443
# side             LAY
# size               5
# 21:41:06.247680
# betId           NaN
# handicap          0
# price          6.76
# selectionId    7337
# side           BACK
# size              5
# 21:41:10.424736
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:41:12.718015
# betId            NaN
# handicap           0
# price            2.7
# selectionId    60443
# side             LAY
# size               5
# 21:41:31.529204
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:41:50.514290
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 21:42:09.407700
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:42:28.013626
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:42:47.855489
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side            LAY
# size              5
# 21:42:52.062082
# betId           NaN
# handicap          0
# price          6.46
# selectionId    7337
# side            LAY
# size              5
# 21:42:56.437084
# betId            NaN
# handicap           0
# price            2.7
# selectionId    60443
# side            BACK
# size               5
# 21:43:16.526925
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:43:35.976021
# betId           NaN
# handicap          0
# price          6.46
# selectionId    7337
# side            LAY
# size              5
# 21:43:54.811702
# betId           NaN
# handicap          0
# price          6.46
# selectionId    7337
# side            LAY
# size              5
# 21:44:13.548415
# betId           NaN
# handicap          0
# price          6.46
# selectionId    7337
# side            LAY
# size              5
# 21:44:32.445754
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:44:51.026550
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:45:10.495998
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:45:30.264787
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:45:49.961975
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:46:09.826874
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:46:28.929673
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:46:47.595936
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:47:07.300776
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:47:26.189384
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:47:44.943968
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:48:03.969967
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:48:23.069520
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:48:42.168777
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:49:02.319696
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:49:21.490470
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:49:40.391609
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:49:59.537429
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:50:18.732891
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:50:37.779289
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:50:56.505651
# betId           NaN
# handicap          0
# price          2.12
# selectionId    7461
# side            LAY
# size              5
# 21:51:00.736418
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:51:05.327408
# betId            NaN
# handicap           0
# price           2.68
# selectionId    60443
# side            BACK
# size               5
# 21:51:23.861247
# betId           NaN
# handicap          0
# price           2.1
# selectionId    7461
# side            LAY
# size              5
# 21:51:28.162312
# betId           NaN
# handicap          0
# price          6.46
# selectionId    7337
# side            LAY
# size              5
# 21:51:32.169106
# betId            NaN
# handicap           0
# price            2.7
# selectionId    60443
# side            BACK
# size               5
# 21:51:51.974132
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:52:11.721933
# betId           NaN
# handicap          0
# price          2.12
# selectionId    7461
# side            LAY
# size              5
# 21:52:16.272162
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:52:20.756596
# betId            NaN
# handicap           0
# price           2.68
# selectionId    60443
# side            BACK
# size               5
# 21:52:40.035478
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:52:58.982949
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:53:18.551262
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:53:37.474594
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:53:56.467377
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:54:16.490580
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:54:35.556246
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:54:54.164436
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:55:13.407974
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:55:33.022201
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:55:52.161697
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:56:12.868235
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:56:32.177261
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:56:51.994762
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:57:11.413729
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:57:30.788420
# betId           NaN
# handicap          0
# price          2.16
# selectionId    7461
# side            LAY
# size              5
# 21:57:35.174157
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:57:39.391629
# betId            NaN
# handicap           0
# price           2.64
# selectionId    60443
# side            BACK
# size               5
# 21:57:58.924391
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:58:18.820078
# betId           NaN
# handicap          0
# price          2.14
# selectionId    7461
# side            LAY
# size              5
# 21:58:23.350961
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:58:42.692508
# betId           NaN
# handicap          0
# price          2.16
# selectionId    7461
# side            LAY
# size              5
# 21:58:47.134542
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:59:06.954595
# betId           NaN
# handicap          0
# price          2.14
# selectionId    7461
# side            LAY
# size              5
# 21:59:11.322605
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:59:30.570317
# betId           NaN
# handicap          0
# price          2.16
# selectionId    7461
# side            LAY
# size              5
# 21:59:34.887149
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 21:59:54.975274
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 22:00:14.678971
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 22:00:34.195072
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:00:53.515854
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:00:57.818194
# betId            NaN
# handicap           0
# price           2.62
# selectionId    60443
# side            BACK
# size               5
# 22:01:17.272126
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:01:36.730020
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:01:55.591685
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:02:14.808135
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:02:33.533854
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:02:37.949785
# betId            NaN
# handicap           0
# price           2.64
# selectionId    60443
# side            BACK
# size               5
# 22:02:56.669204
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:03:01.519539
# betId            NaN
# handicap           0
# price           2.62
# selectionId    60443
# side            BACK
# size               5
# 22:03:20.121459
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:03:38.728352
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:03:57.180377
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:04:15.805603
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:04:34.340875
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:04:52.841174
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:05:11.177299
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:05:30.696343
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:05:34.873876
# betId            NaN
# handicap           0
# price           2.64
# selectionId    60443
# side            BACK
# size               5
# 22:05:53.290925
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:06:11.965823
# betId           NaN
# handicap          0
# price          6.42
# selectionId    7337
# side            LAY
# size              5
# 22:06:16.163150
# betId            NaN
# handicap           0
# price           2.62
# selectionId    60443
# side            BACK
# size               5
# 22:06:32.654076
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:06:36.845975
# betId            NaN
# handicap           0
# price           2.64
# selectionId    60443
# side            BACK
# size               5
# 22:06:55.580680
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:07:14.428765
# betId           NaN
# handicap          0
# price          2.18
# selectionId    7461
# side            LAY
# size              5
# 22:07:18.625732
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:07:37.028939
# betId           NaN
# handicap          0
# price          2.16
# selectionId    7461
# side            LAY
# size              5
# 22:07:41.109929
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:07:59.894987
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:08:04.195696
# betId            NaN
# handicap           0
# price           2.62
# selectionId    60443
# side            BACK
# size               5
# 22:08:22.861787
# betId           NaN
# handicap          0
# price          6.24
# selectionId    7337
# side            LAY
# size              5
# 22:08:27.192306
# betId            NaN
# handicap           0
# price           2.64
# selectionId    60443
# side            BACK
# size               5
# 22:08:45.607047
# betId           NaN
# handicap          0
# price           2.2
# selectionId    7461
# side            LAY
# size              5
# 22:08:49.723778
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:08:53.916645
# betId            NaN
# handicap           0
# price           2.62
# selectionId    60443
# side            BACK
# size               5
# 22:09:12.702444
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:09:31.748744
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:09:50.385945
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:10:09.226134
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:10:27.726846
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:10:46.388422
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:11:05.958335
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:11:24.595414
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:11:43.582442
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:12:02.279182
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:12:21.014725
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:12:39.627557
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:12:58.056121
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:13:17.059647
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:13:35.620374
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:13:54.218753
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:14:12.473108
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:14:31.171114
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:14:49.791594
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:15:08.752234
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:15:27.681200
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:15:46.434948
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:16:05.011250
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:16:23.553408
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:16:42.472270
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:17:00.984290
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:17:19.826246
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:17:38.666565
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:17:57.413448
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:18:16.107163
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:18:34.683177
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:18:53.423023
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:19:12.266154
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:19:30.678210
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:19:49.316368
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:20:07.969225
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:20:26.606914
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:20:45.375182
# betId           NaN
# handicap          0
# price          2.24
# selectionId    7461
# side            LAY
# size              5
# 22:20:49.485066
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:20:53.735496
# betId            NaN
# handicap           0
# price           2.56
# selectionId    60443
# side            BACK
# size               5
# 22:21:12.108483
# betId           NaN
# handicap          0
# price          2.22
# selectionId    7461
# side            LAY
# size              5
# 22:21:16.139268
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:21:20.161355
# betId            NaN
# handicap           0
# price           2.58
# selectionId    60443
# side            BACK
# size               5
# 22:21:38.771297
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:21:42.652649
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:21:46.914879
# betId            NaN
# handicap           0
# price           2.52
# selectionId    60443
# side            BACK
# size               5
# 22:22:05.095075
# betId           NaN
# handicap          0
# price          2.26
# selectionId    7461
# side            LAY
# size              5
# 22:22:09.111798
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:22:13.096988
# betId            NaN
# handicap           0
# price           2.54
# selectionId    60443
# side            BACK
# size               5
# 22:22:31.539044
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:22:35.737608
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:22:39.813005
# betId            NaN
# handicap           0
# price           2.52
# selectionId    60443
# side            BACK
# size               5
# 22:22:58.223491
# betId           NaN
# handicap          0
# price          2.26
# selectionId    7461
# side            LAY
# size              5
# 22:23:02.257289
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:23:06.353357
# betId            NaN
# handicap           0
# price           2.54
# selectionId    60443
# side            BACK
# size               5
# 22:23:24.882158
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:23:43.221172
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:23:47.279951
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:23:51.802925
# betId            NaN
# handicap           0
# price           2.52
# selectionId    60443
# side            BACK
# size               5
# 22:24:10.042019
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:24:30.172603
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:24:48.629130
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:25:07.127878
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:25:25.642860
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:25:43.772273
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:26:02.586435
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:26:21.223003
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:26:39.962897
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:26:58.850242
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:27:17.410448
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:27:37.338051
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:27:56.139787
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:28:14.788527
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:28:33.525529
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:28:52.163594
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:29:10.845866
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:29:29.527287
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:29:48.156413
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:30:07.120221
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:30:25.662911
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:30:44.349461
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:31:03.083837
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:31:21.584588
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:31:40.206101
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:31:58.925343
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:32:17.294343
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:32:35.922892
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:32:40.316081
# betId            NaN
# handicap           0
# price            2.5
# selectionId    60443
# side            BACK
# size               5
# 22:32:58.596966
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:33:17.879532
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:33:36.457402
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:33:55.460492
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:34:14.405752
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:34:18.642658
# betId            NaN
# handicap           0
# price           2.52
# selectionId    60443
# side            BACK
# size               5
# 22:34:37.450833
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:34:41.549749
# betId            NaN
# handicap           0
# price            2.5
# selectionId    60443
# side            BACK
# size               5
# 22:35:00.178313
# betId           NaN
# handicap          0
# price           2.3
# selectionId    7461
# side            LAY
# size              5
# 22:35:04.431461
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:35:08.769028
# betId            NaN
# handicap           0
# price           2.48
# selectionId    60443
# side            BACK
# size               5
# 22:35:27.224613
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:35:31.820364
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:35:35.918425
# betId            NaN
# handicap           0
# price            2.5
# selectionId    60443
# side            BACK
# size               5
# 22:35:54.558266
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:36:13.640438
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:36:32.082390
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:36:50.406920
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:36:54.427893
# betId            NaN
# handicap           0
# price           2.48
# selectionId    60443
# side            BACK
# size               5
# 22:37:13.135242
# betId           NaN
# handicap          0
# price           2.3
# selectionId    7461
# side            LAY
# size              5
# 22:37:17.259691
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:37:35.890418
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:37:39.977464
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:37:58.596815
# betId           NaN
# handicap          0
# price           2.3
# selectionId    7461
# side            LAY
# size              5
# 22:38:02.862507
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:38:21.395915
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:38:25.515343
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:38:43.926093
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:39:02.291216
# betId           NaN
# handicap          0
# price          2.32
# selectionId    7461
# side            LAY
# size              5
# 22:39:06.199731
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:39:10.454986
# betId            NaN
# handicap           0
# price           2.46
# selectionId    60443
# side            BACK
# size               5
# 22:39:28.738039
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:39:47.151195
# betId           NaN
# handicap          0
# price          2.28
# selectionId    7461
# side            LAY
# size              5
# 22:39:51.134098
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:39:55.153283
# betId            NaN
# handicap           0
# price           2.48
# selectionId    60443
# side            BACK
# size               5
# 22:40:11.570846
# betId           NaN
# handicap          0
# price          2.34
# selectionId    7461
# side           BACK
# size              5
# 22:40:16.061044
# betId           NaN
# handicap          0
# price          2.32
# selectionId    7461
# side            LAY
# size              5
# 22:40:20.189920
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:40:24.160971
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:40:28.171155
# betId            NaN
# handicap           0
# price           2.46
# selectionId    60443
# side            BACK
# size               5
# 22:40:30.098992
# betId            NaN
# handicap           0
# price           2.42
# selectionId    60443
# side             LAY
# size               5
# 22:40:48.446418
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:40:52.439001
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:41:10.950700
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:41:15.071152
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:41:33.503130
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:41:37.494092
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:41:55.722355
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:41:59.822219
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:42:18.555329
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:42:22.656015
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:42:41.237697
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:42:45.476531
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 22:42:49.662049
# betId            NaN
# handicap           0
# price           2.44
# selectionId    60443
# side            BACK
# size               5
# 22:43:08.195591
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:43:12.526952
# betId            NaN
# handicap           0
# price           2.44
# selectionId    60443
# side             LAY
# size               5
# 22:43:30.957859
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:43:49.718236
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:43:54.036611
# betId            NaN
# handicap           0
# price           2.42
# selectionId    60443
# side             LAY
# size               5
# 22:44:12.843095
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:44:31.579728
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:44:50.214589
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:44:54.317507
# betId            NaN
# handicap           0
# price           2.44
# selectionId    60443
# side             LAY
# size               5
# 22:45:12.922977
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side            LAY
# size              5
# 22:45:17.094494
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:45:21.453607
# betId            NaN
# handicap           0
# price           2.42
# selectionId    60443
# side             LAY
# size               5
# 22:45:40.191853
# betId           NaN
# handicap          0
# price          2.32
# selectionId    7461
# side            LAY
# size              5
# 22:45:44.388949
# betId           NaN
# handicap          0
# price          6.39
# selectionId    7337
# side           BACK
# size              5
# 22:45:48.494788
# betId            NaN
# handicap           0
# price           2.44
# selectionId    60443
# side             LAY
# size               5
# 22:46:06.833770
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side            LAY
# size              5
# 22:46:11.014236
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:46:12.957521
# betId            NaN
# handicap           0
# price           2.42
# selectionId    60443
# side             LAY
# size               5
# 22:46:29.278340
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side            LAY
# size              5
# 22:46:33.439124
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:46:50.130494
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side            LAY
# size              5
# 22:46:54.106853
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:47:10.825605
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side            LAY
# size              5
# 22:47:14.899815
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:47:33.365302
# betId           NaN
# handicap          0
# price          2.34
# selectionId    7461
# side            LAY
# size              5
# 22:47:37.866654
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:47:57.404578
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:48:15.886925
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:48:34.537216
# betId           NaN
# handicap          0
# price          6.18
# selectionId    7337
# side           BACK
# size              5
# 22:48:38.599285
# betId            NaN
# handicap           0
# price           2.44
# selectionId    60443
# side             LAY
# size               5
# 22:48:56.849537
# betId           NaN
# handicap          0
# price          6.18
# selectionId    7337
# side           BACK
# size              5
# 22:49:15.242592
# betId           NaN
# handicap          0
# price          6.18
# selectionId    7337
# side           BACK
# size              5
# 22:49:31.897026
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side           BACK
# size              5
# 22:49:34.007953
# betId           NaN
# handicap          0
# price          2.34
# selectionId    7461
# side            LAY
# size              5
# 22:49:38.103453
# betId           NaN
# handicap          0
# price          6.18
# selectionId    7337
# side           BACK
# size              5
# 22:49:40.187414
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 22:49:42.112207
# betId            NaN
# handicap           0
# price           2.48
# selectionId    60443
# side            BACK
# size               5
# 22:49:58.446200
# betId           NaN
# handicap          0
# price          2.38
# selectionId    7461
# side           BACK
# size              5
# 22:50:02.543599
# betId           NaN
# handicap          0
# price          2.32
# selectionId    7461
# side            LAY
# size              5
# 22:50:06.741534
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:50:10.821625
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:50:14.810128
# betId            NaN
# handicap           0
# price           2.46
# selectionId    60443
# side            BACK
# size               5
# 22:50:34.697939
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# side           BACK
# size              5
# 22:50:38.869209
# betId           NaN
# handicap          0
# price          6.04
# selectionId    7337
# side            LAY
# size              5
# 22:50:57.121267
# betId           NaN
# handicap          0
# price          2.36
# selectionId    7461
# side           BACK
# size              5
# 22:51:01.168626
# betId           NaN
# handicap          0
# price          6.36
# selectionId    7337
# ...
# selectionId    7461
# side            LAY
# size              5
# 23:31:34.368613
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:31:52.996972
# betId           NaN
# handicap          0
# price          5.93
# selectionId    7337
# side            LAY
# size              5
# 23:32:11.433507
# betId           NaN
# handicap          0
# price          6.17
# selectionId    7337
# side           BACK
# size              5
# 23:32:13.469581
# betId            NaN
# handicap           0
# price           2.56
# selectionId    60443
# side             LAY
# size               5
# 23:32:32.216053
# betId           NaN
# handicap          0
# price          6.17
# selectionId    7337
# side           BACK
# size              5
# 23:32:50.892891
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:32:54.995717
# betId            NaN
# handicap           0
# price            2.6
# selectionId    60443
# side             LAY
# size               5
# 23:33:13.508189
# betId           NaN
# handicap          0
# price           2.2
# selectionId    7461
# side            LAY
# size              5
# 23:33:17.712824
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:33:36.319063
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:33:54.611931
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:34:13.059530
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:34:31.952282
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:34:50.641991
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:35:09.175214
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:35:27.955968
# betId           NaN
# handicap          0
# price          2.22
# selectionId    7461
# side            LAY
# size              5
# 23:35:32.268532
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:35:50.712037
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:36:09.195947
# betId           NaN
# handicap          0
# price           2.2
# selectionId    7461
# side            LAY
# size              5
# 23:36:13.314361
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:36:31.942065
# betId           NaN
# handicap          0
# price          2.22
# selectionId    7461
# side            LAY
# size              5
# 23:36:36.114017
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:36:54.580307
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:37:13.128914
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:37:32.423617
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:37:51.088198
# betId           NaN
# handicap          0
# price          5.89
# selectionId    7337
# side           BACK
# size              5
# 23:38:07.660792
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:38:26.399170
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:38:45.037651
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:39:03.880656
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:39:22.312898
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:39:41.029509
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:40:00.751637
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:40:19.353695
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:40:37.978069
# betId           NaN
# handicap          0
# price          5.81
# selectionId    7337
# side            LAY
# size              5
# 23:40:56.418758
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:41:15.044883
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:41:33.588602
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:41:52.092419
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:42:10.628578
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:42:29.244495
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:42:47.933582
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 23:43:06.570730
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 23:43:25.096012
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 23:43:43.947099
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 23:44:02.662514
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:44:21.120051
# betId           NaN
# handicap          0
# price          6.02
# selectionId    7337
# side            LAY
# size              5
# 23:44:39.755845
# betId           NaN
# handicap          0
# price          6.22
# selectionId    7337
# side            LAY
# size              5
# 23:44:58.290655
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 23:45:16.882814
# betId           NaN
# handicap          0
# price          6.44
# selectionId    7337
# side            LAY
# size              5
# 23:45:35.483738
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:45:54.189033
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:46:12.939509
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:46:31.579455
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:46:50.281229
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:47:08.843466
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:47:27.189951
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:47:45.881056
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:48:04.438348
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# 23:48:22.870768
# betId           NaN
# handicap          0
# price          6.26
# selectionId    7337
# side            LAY
# size              5
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x138852240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     375         if new_retry.is_exhausted():
# --> 376             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     377
#
# MaxRetryError: HTTPSConnectionPool(host='api.betfair.com', port=443): Max retries exceeded with url: /exchange/betting/json-rpc/v1/ (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x138852240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-37-5c81ae3442e2> in <module>
#       1 bot.TEST_MODE = False
# ----> 2 bot.run()
#
# ~/src/blocmarket/bots/BetfairBot.py in run(self)
#     253             targetOrders = []
#     254             time.sleep(self.updateFrequency)
# --> 255             self.getOrderBook()
#     256             self.scrapeCurrentQuote()
#     257             self.getCurrentOrders()
#
# ~/src/blocmarket/bots/BetfairBot.py in getOrderBook(self)
#     107         # Get current order book
#     108
# --> 109         orderBook = bf.listMarketBook(sessionKey=self.betfairSessionKey, appKey=self.betfairAppKey, marketIds=self.betfairMarketId, priceProjection={"priceData":["EX_BEST_OFFERS"]})
#     110
#     111         if orderBook == []:
#
# ~/src/blocmarket/bots/betfair/listMarketBook.py in listMarketBook(sessionKey, appKey, **kwargs)
#     123                "id": 1}
#     124
# --> 125     response = requests.get(urlUK, data=json.dumps(content), headers=headers)
#     126
#     127     orderBook = response.json()['result']
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.betfair.com', port=443): Max retries exceeded with url: /exchange/betting/json-rpc/v1/ (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x138852240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
bot.getCurrentOrders()
